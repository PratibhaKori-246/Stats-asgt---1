# %% [markdown]
# ### Statistics Assignment
# ## BASIC OF STATISTICS

# %% [markdown]
# Q 1. Explain the different type of data and provide examples of each.  discuss nominal ordinal interval and ratio scales.

# %% [markdown]
# Data is broadly classified into two main categories: qualitative (or categorical) and quantitative (or numerical) data.
#
# ## 1. Qualitative Data (Categorical Data)
#
# Definition: Qualitative data describes characteristics or attributes that cannot be measured in numerical terms. This type of data represents qualities, names, or labels rather than quantities.
#
# Characteristics:
#
# Often descriptive or thematic.
# Cannot be measured on a numeric scale.
# Generally used to classify or categorize things.
# Analysis is usually done by counting frequencies or identifying patterns.
#
# Examples of Qualitative Data:
#
# 1. Color of Cars: Red, Blue, Black, White (describes the attribute of color but not measurable numerically).
#
# 2. Customer Feedback: Positive, Neutral, Negative (indicates general sentiment but not on a quantifiable scale).
#
# ##  2. Quantitative Data (Numerical Data)
#
# Definition: Quantitative data represents measurable quantities or amounts and can be expressed in numerical terms. This type of data allows for mathematical calculations and a broader range of statistical analyses.
#
# Characteristics:
#
# 1. Numerical and can be subjected to arithmetic operations.
#
# 2. Can be either discrete (countable) or continuous (measurable).
#
# 3. Enables a wide range of statistical analyses, including calculations of mean, median, standard deviation, and more.
#
# Examples of Quantitative Data:
#
# Age: 25, 32, 40, 18 (expresses age in numbers and allows for arithmetic operations).
#
# ## Type :
# Data can be classified into different types based on its properties and how it can be measured or analyzed. The main types of data are nominal, ordinal, interval, and ratio.
#
# ### 1. Nominal Data
#
# Definition:
#
# Nominal data is the most basic level of data measurement. It represents categories that have no inherent order or ranking. The data points are simply labels or names, used to identify or classify items.
#
# Characteristics:
#
# Categories are mutually exclusive and exhaustive.
# No logical order or rank.
# Often used in classification.
#
# Examples:
#
# Gender: Male, Female, Non-Binary
#
# Blood Type: A, B, AB, O
#
# Marital Status: Single, Married, Divorced, Widowed
#
# Eye Color: Blue, Brown, Green, Hazel
#
# Since nominal data represents categorical information without any quantitative value, you can only use frequency counts or percentages to analyze it.
#
# ### 2. Ordinal Data
#
# Definition:
#
# Ordinal data represents categories with a meaningful order or ranking, but the differences between values are not uniform or measurable. This type of data shows relative positioning but not the magnitude of difference.
#
# Characteristics:
#
# Data has a meaningful order, but intervals between values are not consistent or defined.
# Rank-based, but the exact difference between ranks is unknown.
#
# Examples:
#
# Customer Satisfaction Rating: Very Unsatisfied, Unsatisfied, Neutral, Satisfied, Very Satisfied
#
# Pain Scale: Mild, Moderate, Severe
#
# Socioeconomic Status: Low, Middle, High
#
# Ordinal data allows for comparisons like "greater than" or "less than" but not for mathematical operations like addition or subtraction.
#
# ### 3. Interval Data
#
# Definition:
#
# Interval data is numerical data that has an ordered scale with equal intervals between values, but it lacks an absolute zero point. This means that while you can measure the difference between values, there’s no true zero, making it impossible to calculate meaningful ratios.
#
# Characteristics:
#
# Ordered with equal intervals between units.
# No true zero point; zero doesn’t mean "absence" of the attribute.
# Allows addition and subtraction but not meaningful multiplication or division.
#
# Examples:
#
# Temperature in Celsius or Fahrenheit: The difference between 20°C and 30°C is the same as between 30°C and 40°C, but 0°C does not mean "no temperature."
#
# ### 4. Ratio Data
#
# Definition:
#
# Ratio data is the highest level of measurement and includes all the properties of interval data, with the addition of a meaningful, absolute zero point. This means that both the differences and ratios between values are meaningful.
#
# Characteristics:
#
# Ordered, with equal intervals between values.
# Has a true zero point, indicating the absence of the attribute.
# Allows for all arithmetic operations, including meaningful ratios.
#
# Examples:
#
# Height: A height of 0 cm means no height. You can say that someone who is 180 cm tall is twice as tall as someone who is 90 cm.

# %% [markdown]
# Q 2.What are the measures of Central tendency and when should be used each ? discuss the mean median and mode with example and situations where each is appropriate.

# %% [markdown]
# Measures of central tendency are statistical tools used to summarize a set of data by identifying the central or typical value in a dataset. These measures help us understand the "center" of a data distribution and provide a representative value for the entire dataset. The three primary measures of central tendency are mean, median, and mode.
#
# ### 1. Mean (Arithmetic Average)
#
# Definition: The mean is the sum of all data values divided by the number of values in the dataset.
#
# Formula:
#              Mean = ∑ x / n
#
# where ∑x is the sum of all data points, and n is the total number of data points.
#
# 🔸When to use:
#
# • The mean is appropriate when the data is normally distributed or symmetric, without extreme outliers.
#
# • It is the most commonly used measure of central tendency in many contexts because it uses all data points.
#
# • The mean is sensitive to outliers and skewed data. If the dataset contains extreme values, the mean can be misleading.
#
# ### 2. Median
#
# Definition: The median is the middle value in a dataset when the values are arranged in ascending or descending order. If there is an even number of observations, the median is the average of the two middle values.
#
# Formula:
#
# • If the number of observations (n) is odd:
#
# Median = Value at the position (𝑛+1)/2
#
# • If the number of observations (n) is even:
#
# Median = {Value at the position (n/2) + Value at position (n/ 2 + 1)} / 2
#
# 🔸When to use:
#
# The median is ideal for data that is skewed or contains outliers, because it is not influenced by extreme values.
# It is useful when you need to represent the "typical" value in a distribution where the mean might be distorted by outliers.
#
# Example: In the dataset 20, 22, 25, 27, and 100, the median is 25, even though the mean would be significantly higher (38.8) due to the outlier (100).
#
# ### 3. Mode
#
# Definition: The mode is the value that occurs most frequently in a dataset. A dataset may have no mode (if all values occur with equal frequency), one mode (unimodal), or more than one mode (bimodal or multimodal).
#
# 🔸When to use:
#
# • The mode is useful for categorical data (nominal data) where we want to know which category or value appears most often.
#
# • It is also helpful when you are dealing with discrete data and want to find the most frequent occurrence.
#
# • The mode is not affected by extreme values or outliers, but it may not always represent the "center" in the same way the mean or median does.
#
# Example:
#
# 1 Survey Responses: If you ask a group of people to pick their favorite fruit, and the responses are:
#
# 2 Apple, Banana, Apple, Apple, Orange The mode is Apple, as it occurs most frequently.

# %% [markdown]
# Q 3. Explain the concept of dispersion . How do variance and standard deviation measure the spread of data ?

# %% [markdown]
# Dispersion refers to the extent to which data points in a dataset spread out or vary from the central tendency (mean, median, or mode). In other words, it measures the "spread" or "variability" of data. Dispersion is an important concept in statistics because it helps us understand the degree of consistency or variability within a dataset.
#
# ##  Why Dispersion is Important
#
# ▹ Understanding Consistency: Low dispersion indicates that data points are close to each other, meaning the dataset is consistent.
#
# ▹ Identifying Risk or Uncertainty: In financial or economic contexts, high dispersion might indicate greater uncertainty or risk.
#
# ▹ Making Comparisons: Dispersion allows us to compare the variability between different datasets, which is useful in fields like quality control and performance analysis.
#
# When we talk about the spread of data, we're interested in how close or far the individual data points are from the central value, usually the mean. Variance and standard deviation are key tools for this because they quantify that spread.
#
# Here's how they work:
#
# ### 1. Variance – Captures the "Average Spread" of Data
#
# • Variance calculates the average of the squared differences between each data point and the mean.
#
# • By squaring the differences, it makes all values positive (since distances shouldn’t be negative) and gives greater weight to larger differences. This means that data points farther from the mean have a bigger impact on the variance.
#
# ![image.png](attachment:29b83fe8-5d76-4a86-9073-e2a071514f04.png)
#
# ![image.png](attachment:55183c51-19b0-47f0-826c-293c96afed29.png)
#
# ### 2. Standard Deviation – Measures Spread in Original Units
#
# • Standard deviation is simply the square root of variance.
#
# • By taking the square root, we return to the original units of the data, making it easier to interpret than variance, which is in squared units.
#
# ![image.png](attachment:d44019b3-4137-46d5-aa38-1ee317cd3540.png)

# %% [markdown]
# Q 4. what is a box plot and what can it tell you about the distribution of data.

# %% [markdown]
# A box plot (or box-and-whisker plot) is a graphical representation of the distribution of a dataset. It provides a summary of the data by displaying key statistics in a compact form, helping to visualize the spread and skewness of the data, as well as identify outliers.
#
# #### What a Box Plot Tells You About the Distribution
#
# 1. Center of the Data:
#
# The median line shows the center of the data. If the median is near the center of the box, the data may be symmetrically distributed. A median closer to one end suggests a skewed distribution.
#
# 2. Spread and Variability:
#
# The length of the box (IQR) shows how spread out the middle 50% of the data is. A larger IQR indicates higher variability, while a smaller IQR suggests that the data points are closer to each other.
#
# 3. Skewness:
#
# If the box is not centered within the whiskers or if the whiskers are unequal in length, the distribution may be skewed.
# For example, a longer right whisker indicates right-skewed data (a "tail" to the right), while a longer left whisker indicates left-skewed data.
#
# 4. Outliers:
#
# Outliers are points outside 1.5 times the IQR from Q1 and Q3. They show observations that are unusually high or low, potentially indicating data entry errors, unusual cases, or interesting deviations.
#
# 5. Comparison of Multiple Distributions:
#
# When comparing multiple box plots side by side (e.g., for different groups), you can quickly see differences in medians, IQRs, skewness, and outliers between groups, which is helpful in comparative analysis.

# %% [markdown]
# Q 5. discuss the role of random sampling in making interference about population.

# %% [markdown]
# Random sampling plays a crucial role in making valid and reliable inferences about a population based on a sample. It is a process in which each member of the population has an equal chance of being selected for the sample, ensuring that the sample is representative of the entire population.
#
# ### 1. Reducing Bias and Increasing Representativeness
#
# Randomness in sampling helps avoid selection bias, where certain groups or characteristics in the population might be overrepresented or underrepresented in the sample.
# When each member has an equal chance of selection, the sample more accurately reflects the diversity of the population in terms of characteristics, behaviors, or responses.
# This representativeness is essential because inferences drawn from a biased sample may lead to incorrect conclusions about the population.
#
# ### 2. Facilitating Generalization to the Population
#
# The goal of inferential statistics is to use sample data to make predictions or draw conclusions about the larger population.
# Because a random sample is representative, the statistics calculated from it (such as means, proportions, and variances) are more likely to approximate the true values in the population.
# For example, in estimating the average height of people in a city, a random sample of heights will produce a more reliable estimate than a non-random sample (e.g., heights measured only at a basketball court).
#
# ### 3. Allowing for Estimation of Sampling Error
#
# Random sampling allows for the calculation of sampling error, the natural variability that arises when using a sample instead of the entire population.
# Sampling error can be quantified with concepts like confidence intervals and margin of error, providing a range of values that likely includes the true population parameter.
# This error estimation is only possible because of randomness; without it, there would be no basis for calculating how sample results vary from one sample to another.
#
# ### 4. Enabling Use of Probabilistic Methods for Hypothesis Testing
#
# Random sampling underpins the use of probabilistic methods, such as hypothesis testing, in inferential statistics.
# Since the sample is chosen randomly, the probability theory applies, allowing statisticians to estimate the likelihood of observing certain sample results if a particular hypothesis about the population is true.
# For example, in hypothesis testing, random sampling supports calculating a p-value, which indicates the probability of observing the sample data (or something more extreme) if the null hypothesis is true.

# %% [markdown]
# Q 6. Explain the concept of skewness and its type . How does skewness affect the interpretation of data?

# %% [markdown]
# Skewness is a measure of the asymmetry, or lack of symmetry, in the distribution of data values around the mean. It indicates whether the data points are spread more toward the left or right of the mean, or if the data is symmetric.
#
# ### Types of Skewness
#
# #### 1.Symmetric Distribution (Zero Skewness):
#
# When the distribution is symmetric, it has no skew (or zero skewness). In this case, the data values are evenly distributed around the mean.
#
# In a symmetric distribution, the mean, median, and mode are typically the same or very close in value.
#
# #### 2.Positive Skew (Right Skew):
#
# In a positively skewed distribution, the tail on the right side (higher values) is longer or fatter than the left side.
#
# Most data points in a positively skewed distribution are concentrated on the left, with fewer larger values on the right.
#
# In this case, the mean is typically greater than the median, and the median is greater than the mode.
#
# #### 3.Negative Skew (Left Skew):
#
# In a negatively skewed distribution, the tail on the left side (lower values) is longer or fatter than the right side.
#
# Most data points are concentrated on the right, with fewer smaller values on the left.
#
# Here, the mean is typically less than the median, and the median is less than the mode.
#
# #### 4.Quantifying Skewness
#
# Skewness can be quantified with a skewness coefficient, calculated using statistical formulas.
#
# A skewness value of:
#
# • 0 indicates a symmetric distribution.
#
# • Greater than 0 suggests positive skewness.
#
# • Less than 0 suggests negative skewness.
#
# skewness significantly influences how we interpret data by impacting the choice of measures of central tendency, affecting the spread, determining the suitability of statistical tests, influencing the detection of outliers, and shaping data visualization.

# %% [markdown]
# Q 7. What is interquartile range (IQR) and . How is it used to detect outliers ?

# %% [markdown]
# The interquartile range (IQR) is a measure of statistical dispersion, representing the range within which the middle 50% of a dataset lies. It's calculated by finding the difference between the first quartile (Q1) and the third quartile (Q3) of a data :
#
# ![image.png](attachment:7ea3defb-afc1-4e7d-9d98-9db3c463dfd8.png)
#
# Steps to Calculate the IQR:
#
# 1. Sort the data in ascending order.
#
# 2. Find the first quartile (Q1), which is the median of the lower
# half of the data (25th percentile).
#
# 3. Find the third quartile (Q3), which is the median of the upper half of the data (75th percentile).
#
# 4. Subtract Q1 from Q3 to get the IQR.
#
#
# Steps for Detecting Outliers with IQR :
#
# ![image.png](attachment:0471a172-ab24-4f4d-9eaa-43426da49b0a.png)
#
# example:
#
# ![image.png](attachment:d326e1a4-086c-473c-a06d-dd6257d526af.png)

# %% [markdown]
# Q 8. Discuss the conditions under which the Binomial Distribution is used ?

# %% [markdown]
# The binomial distribution is used to model the probability of observing a specific number of "successes" in a fixed number of independent trials, where each trial has only two possible outcomes.
#
# For a binomial distribution to apply, certain conditions need to be met:
#
# 1. Fixed Number of Trials (n)
#
# There must be a set number of trials, denoted by 𝑛 .
#
# Each trial is independent of the others, meaning that the outcome of one trial does not affect the outcome of another.
#
# 2. Only Two Possible Outcomes per Trial
#
# Each trial must result in one of two possible outcomes, typically referred to as "success" (e.g., flipping heads on a coin) or "failure" (e.g., flipping tails on a coin).
#
# These two outcomes are mutually exclusive, meaning a trial cannot result in both a "success" and a "failure."
#
# 3. Constant Probability of Success (p)
#
# The probability of success, 𝑝 p, must remain constant across all trials.
#
# For example, in a fair coin flip, the probability of getting heads (a "success") is always 0.5 in each flip.
#
# 4. Independence of Trials
#
# Each trial must be independent of all others, meaning the outcome of one trial does not affect the probability of success or failure in another trial.
#
# ![image.png](attachment:6dc74f1f-69b0-4767-a47f-837bb057c22f.png)

# %% [markdown]
# Q 9. Explain the properties of distribution and empirical rule (68 - 95 - 99.7 rule).

# %% [markdown]
# The properties of a normal distribution and the empirical rule (also known as the 68-95-99.7 rule) are key concepts in statistics, particularly in the study of data that follow a normal (Gaussian) distribution.
#
# ### Properties of a Normal Distribution
#
# A normal distribution is a continuous probability distribution that is symmetric about its mean, and it has a characteristic "bell curve" shape. Here are its main properties:
#
# 1. Symmetry Around the Mean:
#
# The normal distribution is symmetric, meaning it has a mirror-image shape around the mean.
# The mean, median, and mode are all located at the center and are equal.
#
# 2. Bell-Shaped Curve:
#
# The distribution is shaped like a bell, with most data points concentrated around the mean.
# As you move farther away from the mean, the frequency of data points decreases.
#
# 3. Defined by Mean (μ) and Standard Deviation (σ):
#
# The shape and spread of a normal distribution are determined by its mean (μ) and standard deviation (σ).
# The mean indicates the center of the distribution, while the standard deviation measures the spread or dispersion around the mean.
#
# 4. Asymptotic Nature:
#
# The tails of a normal distribution approach, but never touch, the horizontal axis. This implies that extreme values are possible, but they become increasingly rare as they move away from the mean.
#
# 5. Total Area Under the Curve is 1:
#
# The area under the entire curve of a normal distribution equals 1 (or 100% probability), representing the sum of all probabilities for all possible values.
#
# #### The Empirical Rule (68-95-99.7 Rule)
#
# The empirical rule is a shortcut for understanding the spread of data in a normal distribution. It states that for data following a normal distribution:
#
# 1. 68% of Data Within One Standard Deviation (±1σ):
#
# Approximately 68% of the data will lie within one standard deviation from the mean, i.e., in the interval [μ - σ, μ + σ].
#
# 2. 95% of Data Within Two Standard Deviations (±2σ):
#
# About 95% of the data will fall within two standard deviations of the mean, i.e., in the interval [μ - 2σ, μ + 2σ].
#
# 3. 99.7% of Data Within Three Standard Deviations (±3σ):
#
# Almost all (99.7%) of the data will be within three standard deviations of the mean, i.e., in the interval [μ - 3σ, μ + 3σ].

# %% [markdown]
# Q 10. Provide a areal - life examples of a poisson process and calculate the probability for a specific event .

# %% [markdown]
# A Poisson process is often used to model events that happen randomly and independently over a continuous interval, like time, distance, or space. It’s particularly useful for estimating the likelihood of a given number of events occurring within a fixed interval, under the assumption that these events are rare or infrequent.
#
# Real-Life Example of a Poisson Process
# One real-life example of a Poisson process is emergency calls arriving at a fire station. Suppose a fire station receives emergency calls randomly throughout the day. We might use a Poisson distribution to estimate the likelihood of receiving a specific number of calls in a given hour.
#
# For this example, let’s assume:
#
# On average, the fire station receives 3 emergency calls per hour.
# We can calculate the probability of receiving exactly a certain number of calls, say 5 calls, within an hour using the Poisson formula.
#
# ![image.png](attachment:e41d6814-9385-4cf1-8104-d440af25286f.png)
#
# example:
#
# ![image.png](attachment:37416159-3440-440f-ad5d-e949256cb8cc.png)

# %% [markdown]
# Q 11. Explain what a random variable is and differentiate between discrete and continuous random variable.

# %% [markdown]
# A random variable is a variable that represents the possible outcomes of a random phenomenon or experiment. It assigns numerical values to each outcome of an event, allowing us to analyze and compute probabilities in a structured way.
#
# 1. Discrete Random Variable
#
# A discrete random variable is a variable that takes on a finite or countably infinite set of distinct values. Each value has an associated probability, and these probabilities add up to 1.
#
# Examples of Discrete Random Variables:
#
# • Number of heads when flipping a coin 3 times (can be 0, 1, 2, or 3).
#
# • Number of students absent in a class on a given day (could be any non-negative integer).
#
# • Number of customer calls a service center receives in an hour (finite number).
#
# 2. Continuous Random Variable
#
# A continuous random variable is a variable that can take any value within a continuous range. This means it can assume infinitely many values within an interval, such as all real numbers between 0 and 1, or any positive real number.
#
# Examples of Continuous Random Variables:
#
# • Height of students in a school (could be any value within a realistic range).
#
# • Time taken to run a marathon (could be any positive real number, e.g., 3.5 hours, 4.75 hours).
#
# • Temperature at a given location at a particular time (could take any value within a range).
#
# ### Between Discrete and Continuous Random Variables:
#
# ![image.png](attachment:1052ee99-298e-4abb-aaf3-85d2112a64d0.png)

# %% [markdown]
# Q 12. Provide an example database , calculate both covariance and correlation , and interpret the results.

# %% [markdown]
# Let's work with a hypothetical dataset to calculate both covariance and correlation. These two statistical measures are used to assess the relationship between two variables.
#
# #### Example Database
#
# Consider the following dataset of students' study hours (X) and their scores on a test (Y):
#
# ![image.png](attachment:91192f7b-c968-4a36-b219-28e4c37b6ca5.png)
#
# Step 1: Calculate Covariance
#
# Covariance is a measure of the joint variability of two random variables. It indicates whether the two variables tend to increase together (positive covariance), decrease together (negative covariance), or if there is no consistent pattern (near-zero covariance).
#
# ![image.png](attachment:a404de7c-b2f7-4bea-ae69-ebfe3f6ae454.png)
#
# calculating:
#
# step 1
#
# ![image.png](attachment:6fb0c1ae-6ed8-4694-9975-fc6ca48c4888.png)
#
# step 2
#
# ![image.png](attachment:113d2d31-bae0-414a-8b66-1cc99d460ff1.png)
#
# last step:
#
# ![image.png](attachment:34d8d78a-726d-4057-ae08-5902bbcdb7e0.png)
#
# ### Interpretation of Results:
# Covariance = 38.75: This indicates a positive relationship between the variables (study hours and test scores), meaning that as one variable increases, the other tends to increase as well. However, covariance alone doesn't provide information about the strength of the relationship.
#
# Correlation = 0.974: This shows a very strong positive linear relationship between study hours and test scores. A correlation value close to +1 suggests that the variables are highly positively related — in this case, students who study more tend to score higher on the test.
